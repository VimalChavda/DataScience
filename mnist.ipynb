# %% [markdown]
# <a href="https://colab.research.google.com/github/VimalChavda/DataScience/blob/master/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
dataset=tf.keras.datasets.mnist

(X_train,Y_train),(x_test,y_test)=dataset.load_data()

# %%
  X_train,x_test =X_train/255.0,x_test/255.0
  print("shape",X_train.shape)
# Out:
# shape (60000, 28, 28)

# %%
model=tf.keras.models.Sequential([
                                tf.keras.layers.Flatten(input_shape=(28,28)),
                                tf.keras.layers.Dense(128,activation='relu'),
                                tf.keras.layers.Dropout(0.2),
                                tf.keras.layers.Dense(128,activation='relu'),
                                tf.keras.layers.Dropout(0.2),
                                tf.keras.layers.Dense(128,activation='relu'),
                                tf.keras.layers.Dropout(0.2),
                                tf.keras.layers.Dense(10,activation='softmax')
                                  
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
r=model.fit(X_train,Y_train,validation_data=(x_test,y_test),epochs=10,batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 3s 5ms/step - loss: 0.7131 - accuracy: 0.7723 - val_loss: 0.1380 - val_accuracy: 0.9592
# Epoch 2/10
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1822 - accuracy: 0.9468 - val_loss: 0.1040 - val_accuracy: 0.9675
# Epoch 3/10
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1325 - accuracy: 0.9600 - val_loss: 0.1100 - val_accuracy: 0.9644
# Epoch 4/10
# 600/600 [==============================] - 3s 5ms/step - loss: 0.1116 - accuracy: 0.9664 - val_loss: 0.0903 - val_accuracy: 0.9731
# Epoch 5/10
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0974 - accuracy: 0.9693 - val_loss: 0.0880 - val_accuracy: 0.9743
# Epoch 6/10
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0830 - accuracy: 0.9738 - val_loss: 0.0793 - val_accuracy: 0.9753
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'],label='accuracy')
plt.plot(r.history['val_accuracy'],label='val_accuracy')
plt.legend()

# %%
fig = plt.figure()
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.tight_layout()
  plt.imshow(X_train[i], cmap='gray', interpolation='none')
  plt.title("Digit: {}".format(Y_train[i]))
  plt.xticks([])
  plt.yticks([])
fig
